# %% [markdown]
# # Task 1.1 - Construct RLTK Datasets

# %%
# %pip install rltk

import rltk
import csv
import pandas as pd
import numpy as np

# Using pandas to inspect the dataframe and understand the data

source_2 = pd.read_csv('data/Sample - Nutrition Data Self - Source 2.csv')
source_1 = pd.read_csv('data/Sample - Nutrition Value with Categories - Source 1.csv')
flavor = pd.read_csv('data/Flavor DB.csv')

source_2 = source_2.apply(pd.to_numeric, errors="ignore")
source_1 = source_1.apply(pd.to_numeric, errors="ignore")

print(source_2.columns)
print(source_1.columns)
print(flavor.columns)

print(source_2.describe())
print(source_1.describe())

source_2['Food Name'].replace('', np.nan, inplace=True)
source_1['Food Name'].replace('', np.nan, inplace=True)

source_2.dropna(subset=['Food Name'], inplace=True)
source_1.dropna(subset=['Food Name'], inplace=True)

source_2.drop_duplicates('Food Name')
source_1.drop_duplicates('Food Name')

# source_2.to_csv('data/Nutrition Data Self Data UTF-8.csv', encoding="UTF-8")
# source_1.to_csv('data/Nutritional Data with Categories UTF-8.csv', encoding="UTF-8")
# flavor.to_csv('data/Flavor DB UTF-8.csv', encoding="UTF-8")
# Out:
# Index(['Food Name', 'Glycemic Load', 'Completeness Score', 'Amino Acid Score'], dtype='object')
# Index(['Ash', 'Calcium', 'Calories', 'Carbohydrate', 'Copper', 'Fat', 'Iron',
#        'Magnesium', 'Potassium', 'Protein', 'Saturated fatty acids', 'Sodium',
#        'Vitamin A, RAE', 'Vitamin B6', 'Water', 'Zinc', 'Food Name',
#        'Fatty acids, total trans', 'Manganese', 'Vitamin D', 'Sub-Category',
#        'Category'],
#       dtype='object')
# Index(['Food', 'Matching Food', 'Category of Matching Food',
#        'Number of common flavor molecules'],
#       dtype='object')
#        Glycemic Load  Completeness Score  Amino Acid Score
# count     535.000000          535.000000        340.000000
# mean        8.082243           40.177570         93.402941
# std        22.397682           24.313578         43.987857
# min         0.000000            0.000000          0.000000
# 25%         0.000000           23.000000         68.000000
# 50%         2.000000           37.000000         94.500000
# 75%         8.000000           55.000000        133.250000
# max       304.000000           93.000000        181.000000
#               Ash      Calcium     Calories  Carbohydrate      Copper  \
# count  837.000000   931.000000   953.000000    953.000000  774.000000
# mean     1.116774    43.708260   128.905771     13.389035    0.136576
# std      1.435812   104.245673   147.382576     22.731356    0.999668
# min      0.000000     0.000000     0.000000      0.000000    0.000000
# 25%      0.270000     2.945000    42.000000      0.840000    0.010000
# 50%      0.750000    11.900000   105.000000      6.960000    0.050000
# 75%      1.320000    39.665000   159.000000     19.000000    0.100000
# max     12.410000  1196.000000  1685.000000    385.520000   26.640000
#
#               Fat        Iron   Magnesium    Potassium     Protein  \
# count  953.000000  935.000000  796.000000   858.000000  952.000000
# mean     5.423931    1.036791   19.397688   182.610758    6.745420
# std      8.379127    2.659900   37.024845   227.951292   12.694137
# min      0.000000    0.000000    0.000000     0.000000    0.000000
# 25%      0.351000    0.090000    3.307500    27.225000    0.690000
# 50%      2.754000    0.470000   12.645000   106.035000    2.025000
# 75%      7.672000    0.950000   23.800000   269.087500    7.397500
# max     96.500000   43.000000  770.000000  2563.110000  254.670000
#
#        Saturated fatty acids       Sodium  Vitamin A, RAE  Vitamin B6  \
# count             904.000000   940.000000      740.000000  788.000000
# mean                1.867494   204.361638       42.631081    0.175179
# std                 3.130248   350.051834      134.733485    0.360567
# min                 0.000000     0.000000        0.000000    0.000000
# 25%                 0.082000    16.950000        0.000000    0.012000
# 50%                 0.880000    80.965000        4.250000    0.057500
# 75%                 2.135250   227.740000       27.170000    0.225000
# max                40.970000  3806.990000     1495.440000    7.163000
#
#              Water        Zinc  Fatty acids, total trans   Manganese  \
# count   838.000000  787.000000                559.000000  659.000000
# mean     59.550907    0.893520                  0.083030    0.231680
# std      81.000824    1.379539                  0.316563    1.440934
# min       0.000000    0.000000                  0.000000    0.000000
# 25%       7.657500    0.100000                  0.000000    0.009000
# 50%      30.910000    0.370000                  0.000000    0.036000
# 75%      82.182500    1.145000                  0.032000    0.190500
# max    1118.880000   13.120000                  5.001000   35.000000
#
#         Vitamin D
# count  550.000000
# mean     0.314145
# std      1.244520
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.260000
# max     18.340000
#       Ash  Calcium  Calories  Carbohydrate  Copper    Fat  Iron  Magnesium  \
# 0    1.72    13.11     127.0          2.13    0.06  9.280  1.17      13.68
# 1    0.76    18.72     103.0         19.35    0.05  2.184  0.34      16.32
# 2    0.37     5.39     123.0         21.72    0.08  4.224  0.56      11.34
# 3    0.94    52.45      95.0         13.72    0.03  3.430  0.58       7.09
# 4     NaN     0.00     100.0         21.00     NaN  2.499  0.72        NaN
# ..    ...      ...       ...           ...     ...    ...   ...        ...
# 948  0.99    15.82     149.0          0.00    0.12  6.452  1.36      24.86
# 949  0.61    87.00      93.0         12.15     NaN  1.710  0.03        NaN
# 950   NaN     0.00     150.0         18.00     NaN  6.999  0.40        NaN
# 951  0.16     1.30      26.0          0.96    0.00  1.758  0.08       1.30
# 952  1.10   190.89      78.0         19.60    0.38  0.000  3.44      45.78
#
#      Potassium  Protein  ...  Vitamin A, RAE  Vitamin B6  Water  Zinc  \
# 0       147.63     8.70  ...            0.00       0.085  35.17  3.47
# 1        60.96     1.59  ...             NaN       0.036  24.12  0.26
# 2        62.09     1.13  ...            0.28       0.019   0.79  0.18
# 3        53.30     2.07  ...            7.37       0.019   8.19  0.17
# 4        89.90     3.00  ...             NaN         NaN    NaN   NaN
# ..         ...      ...  ...             ...         ...    ...   ...
# 948     383.07    21.16  ...            0.00       0.589  83.97  3.80
# 949        NaN     7.22  ...           25.00         NaN  78.40   NaN
# 950       0.00     3.00  ...             NaN         NaN    NaN   NaN
# 951      23.79     1.51  ...            5.46       0.014   8.60  0.14
# 952       0.00     0.00  ...          286.65       0.382   0.30  2.86
#
#                                              Food Name  \
# 0                                    Roast beef spread
# 1        Van's, Totally Original Pancakes, Gluten Free
# 2                  Cookies, regular, dry mix, brownies
# 3     Biscuits, prepared, dry mix, plain or buttermilk
# 4        Act ii kettle corn, 8.75 oz by Conagra Brands
# ..                                                 ...
# 948  Pork, raw, separable lean only, blade (steaks)...
# 949            Yogurt, CHOBANI, apricot, 2% fat, Greek
# 950  Annie's organic cheddar snack mix by GENERAL M...
# 951                      Poultry salad sandwich spread
# 952           Beverages, Classic Malt powder, OVALTINE
#
#      Fatty acids, total trans Manganese  Vitamin D      Sub-Category  \
# 0                         NaN       NaN        NaN               NaN
# 1                       0.006     0.444        NaN               NaN
# 2                         NaN     0.100        NaN  Crusts_AND_Dough
# 3                         NaN     0.071        NaN          Tomatoes
# 4                       0.000       NaN        NaN               NaN
# ..                        ...       ...        ...               ...
# 948                     0.043     0.015       0.68               NaN
# 949                     0.070       NaN        NaN               NaN
# 950                     0.000       NaN        NaN               NaN
# 951                       NaN     0.001       0.03               NaN
# 952                     0.000       NaN       1.91          Tomatoes
#
#              Category
# 0       Branded Foods
# 1       Branded Foods
# 2       Branded Foods
# 3    Foundation Foods
# 4                 NaN
# ..                ...
# 948     Branded Foods
# 949     Branded Foods
# 950               NaN
# 951     Branded Foods
# 952  Foundation Foods
#
# [948 rows x 22 columns]

# %%
unique_flavors_1 = set(list(flavor['Food']))
unique_flavors_2 = set(list(flavor['Matching Food']))
unique_flavors = unique_flavors_1.union(unique_flavors_2)
unique_flavors = list(unique_flavors)

flavor_dict = dict()

for i in unique_flavors:
    flavor_dict[i] = list()
    for index, row in source_2.iterrows():
        tokens = row['Food Name'].split()
        if(i.lower() in tokens):
            flavor_dict[i].append(row['Food Name'])

# %%
# Create record schema for both data sources

tokenizer = rltk.tokenizer.crf_tokenizer.crf_tokenizer.CrfTokenizer()
import re

class Flavor(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''
    
    @rltk.cached_property
    def id(self):
        return str(self.raw_object['Food']+self.raw_object['Matching Food'])
    
    @rltk.cached_property
    def food1(self):
        if(len(self.raw_object['Food']) == 0):
            return ' '
        else:
            return str(self.raw_object['Food'])
    
    @rltk.cached_property
    def food1_tokens(self):
        return set(tokenizer.tokenize(self.food1))
    
    @rltk.cached_property
    def food2(self):
        if(len(self.raw_object['Matching Food']) == 0):
            return ' '
        else:
            return str(self.raw_object['Matching Food'])
    
    @rltk.cached_property
    def food2_tokens(self):
        return set(tokenizer.tokenize(self.food2))
    
    @rltk.cached_property
    def weight(self):
        return self.raw_object['Number of common flavor molecules']
    


class Source1Record(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''
    
    @rltk.cached_property
    def id(self):
        return self.raw_object['Food Name']

    @rltk.cached_property
    def name_string(self):
        if(len(self.raw_object['Food Name']) == 0):
            return ' '
        else:
            return str(self.raw_object['Food Name'])
    
    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))
    
    @rltk.cached_property
    def Category(self):
        return self.raw_object['Category']

    @rltk.cached_property
    def Sub_Category(self):
        return self.raw_object['Sub-Category']

    @rltk.cached_property
    def Ash(self):
        return self.raw_object['Ash']
    
    @rltk.cached_property
    def Calcium(self):
        return self.raw_object['Calcium']
    
    @rltk.cached_property
    def Calories(self):
        return self.raw_object['Calories']
    
    @rltk.cached_property
    def Carbohydrate(self):
        return self.raw_object['Carbohydrate']
    
    @rltk.cached_property
    def Copper(self):
        return self.raw_object['Copper']
    
    @rltk.cached_property
    def Fat(self):
        return self.raw_object['Fat']
    
    @rltk.cached_property
    def Iron(self):
        return self.raw_object['Iron']
    
    @rltk.cached_property
    def Magnesium(self):
        return self.raw_object['Magnesium']
    
    @rltk.cached_property
    def Potassium(self):
        return self.raw_object['Potassium']
    
    @rltk.cached_property
    def Protein(self):
        return self.raw_object['Protein']

    @rltk.cached_property
    def Saturated_fatty_acids(self):
        return self.raw_object['Saturated fatty acids']
    
    @rltk.cached_property
    def Sodium(self):
        return self.raw_object['Sodium']
    
    @rltk.cached_property
    def Vitamin_A_RAE(self):
        return self.raw_object['Vitamin A, RAE']
    
    @rltk.cached_property
    def Vitamin_B6(self):
        return self.raw_object['Vitamin B6']
    
    @rltk.cached_property
    def Water(self):
        return self.raw_object['Water']
    
    @rltk.cached_property
    def Zinc(self):
        return self.raw_object['Zinc']
    
    @rltk.cached_property
    def Fatty_acids_total_trans(self):
        return self.raw_object['Fatty acids, total trans']
    
    @rltk.cached_property
    def Manganese(self):
        return self.raw_object['Manganese']
    
    @rltk.cached_property
    def Vitamin_D(self):
        return self.raw_object['Vitamin D']

class Source2Record(rltk.Record):
    def __init__(self, raw_object):
        super().__init__(raw_object)
        self.name = ''
    
    @rltk.cached_property
    def id(self):
        return self.raw_object['Food Name']

    @rltk.cached_property
    def name_string(self):
        if(len(self.raw_object['Food Name']) == 0):
            return ' '
        else:
            return str(self.raw_object['Food Name'])
    
    @rltk.cached_property
    def name_tokens(self):
        return set(tokenizer.tokenize(self.name_string))

    @rltk.cached_property
    def Glycemic_Load(self):
        return self.raw_object['Glycemic Load']

    @rltk.cached_property
    def Completeness_Score(self):
        return self.raw_object['Completeness Score']

    @rltk.cached_property
    def Amino_Acid_Score(self):
        return self.raw_object['Amino Acid Score']

# %%
flavor_ds = rltk.Dataset(rltk.CSVReader('data/Flavor DB UTF-8.csv'), record_class=Flavor)
ds2 = rltk.Dataset(rltk.CSVReader('data/Sample - Nutrition Data Self - Source 2.csv'), record_class=Source2Record)
ds1 = rltk.Dataset(rltk.CSVReader('data/Sample - Nutrition Value with Categories - Source 1.csv'), record_class=Source1Record)
# ds1 = rltk.Dataset(rltk.DataFrameReader(df_utf8), record_class=Source1Record)

# %% [markdown]
# # Task 1.2 - Blocking

# %%
# Cleaning pipeline and comparision functions

import string
import math

def toLower(text):
    return str(text).lower()

def extraSpaces(text):
    return re.sub(' +', ' ', text, flags=re.MULTILINE)

def removeNum(text):
    return re.sub(r'[0-9]+', '', text)

def removePunct(text):
    return text.translate(str.maketrans('', '', string.punctuation))

def basicCleaningPipeline(s):
    s1 = toLower(s)
    s1 = removePunct(s1)
    s1 = extraSpaces(s1)
    return s1

def jaccard(r1, r2):
    s1 = r1.name_tokens
    s2 = r2.name_tokens
    
    return rltk.jaccard_index_similarity(s1, s2)

def page(r1, r2):
    p1 = r1.pages
    p2 = r2.pages

    if(abs(p1-p2) < 3):
        return 1
    else:
        return 0

# %%
def compound(name):
    name = basicCleaningPipeline(name)
    size = len(name.split())
    label = str(size-1) + '-' + str(size+1)
    print(label)
    return label

bg = rltk.HashBlockGenerator()
block = bg.generate(
    bg.block(ds1, function_=lambda x: compound(x.name_string)),
    bg.block(ds2, function_=lambda x: compound(x.name_string))
)
# Out:
# 2-4
# 5-7
# 4-6
# 6-8
# 8-10
# 4-6
# 10-12
# 6-8
# 5-7
# 4-6
# 1-3
# 4-6
# 13-15
# 10-12
# 5-7
# 10-12
# 8-10
# 8-10
# 12-14
# 10-12
# 9-11
# 7-9
# 6-8
# 8-10
# 12-14
# 4-6
# 3-5
# 2-4
# 4-6
# 5-7
# 5-7
# 3-5
# 10-12
# 5-7
# 8-10
# 4-6
# 9-11
# 11-13
# 1-3
# 8-10
# 7-9
# 14-16
# 3-5
# 5-7
# 5-7
# 5-7
# 4-6
# 3-5
# 8-10
# 4-6
# 5-7
# 5-7
# 4-6
# 12-14
# 7-9
# 2-4
# 4-6
# 8-10
# 4-6
# 5-7
# 6-8
# 5-7
# 11-13
# 8-10
# 4-6
# 4-6
# 8-10
# 5-7
# 7-9
# 4-6
# 7-9
# 3-5
# 3-5
# 6-8
# 13-15
# 8-10
# 9-11
# 11-13
# 1-3
# 5-7
# 3-5
# 10-12
# 5-7
# 12-14
# 6-8
# 8-10
# 5-7
# 12-14
# 11-13
# 5-7
# 7-9
# 11-13
# 9-11
# 10-12
# 4-6
# 12-14
# 10-12
# 6-8
# 2-4
# 10-12
# 10-12
# 7-9
# 1-3
# 6-8
# 11-13
# 1-3
# 7-9
# 5-7
# 5-7
# 4-6
# 8-10
# 13-15
# 3-5
# 11-13
# 12-14
# 12-14
# 2-4
# 7-9
# 5-7
# 7-9
# 13-15
# 11-13
# 12-14
# 11-13
# 4-6
# 3-5
# 6-8
# 8-10
# 5-7
# 7-9
# 8-10
# 2-4
# 12-14
# 12-14
# 3-5
# 3-5
# 4-6
# 8-10
# 3-5
# 9-11
# 3-5
# 5-7
# 5-7
# 1-3
# 4-6
# 6-8
# 10-12
# 7-9
# 4-6
# 14-16
# 3-5
# 5-7
# 6-8
# 3-5
# 13-15
# 3-5
# 3-5
# 2-4
# 5-7
# 6-8
# 5-7
# 4-6
# 6-8
# 12-14
# 9-11
# 12-14
# 6-8
# 6-8
# 5-7
# 8-10
# 15-17
# 4-6
# 7-9
# 2-4
# 4-6
# 6-8
# 5-7
# 4-6
# 6-8
# 3-5
# 12-14
# 11-13
# 5-7
# 4-6
# 10-12
# 6-8
# 10-12
# 8-10
# 6-8
# 8-10
# 3-5
# 4-6
# 1-3
# 3-5
# 15-17
# 7-9
# 11-13
# 5-7
# 4-6
# 4-6
# 10-12
# 7-9
# 11-13
# 6-8
# 8-10
# 9-11
# 11-13
# 1-3
# 7-9
# 10-12
# 13-15
# 7-9
# 2-4
# 8-10
# 2-4
# 11-13
# 3-5
# 8-10
# 10-12
# 10-12
# 6-8
# 6-8
# 4-6
# 2-4
# 5-7
# 3-5
# 7-9
# 7-9
# 3-5
# 7-9
# 4-6
# 5-7
# 15-17
# 10-12
# 14-16
# 6-8
# 2-4
# 4-6
# 8-10
# 4-6
# 1-3
# 8-10
# 5-7
# 9-11
# 11-13
# 6-8
# 5-7
# 5-7
# 11-13
# 3-5
# 8-10
# 7-9
# 10-12
# 16-18
# 13-15
# 1-3
# 10-12
# 8-10
# 12-14
# 9-11
# 2-4
# 12-14
# 7-9
# 1-3
# 3-5
# 14-16
# 14-16
# 1-3
# 7-9
# 5-7
# 2-4
# 6-8
# 4-6
# 6-8
# 8-10
# 8-10
# 6-8
# 6-8
# 14-16
# 10-12
# 10-12
# 8-10
# 10-12
# 4-6
# 9-11
# 7-9
# 10-12
# 7-9
# 6-8
# 13-15
# 8-10
# 6-8
# 6-8
# 8-10
# 3-5
# 3-5
# 7-9
# 7-9
# 10-12
# 3-5
# 11-13
# 4-6
# 3-5
# 3-5
# 2-4
# 5-7
# 6-8
# 11-13
# 3-5
# 1-3
# 5-7
# 5-7
# 8-10
# 2-4
# 6-8
# 5-7
# 2-4
# 5-7
# 4-6
# 6-8
# 4-6
# 7-9
# 16-18
# 9-11
# 9-11
# 4-6
# 7-9
# 7-9
# 4-6
# 7-9
# 11-13
# 4-6
# 14-16
# 5-7
# 5-7
# 9-11
# 13-15
# 8-10
# 8-10
# 4-6
# 4-6
# 12-14
# 7-9
# 7-9
# 8-10
# 3-5
# 12-14
# 4-6
# 6-8
# 5-7
# 7-9
# 6-8
# 4-6
# 7-9
# 4-6
# 4-6
# 9-11
# 12-14
# 5-7
# 3-5
# 10-12
# 4-6
# 9-11
# 10-12
# 6-8
# 7-9
# 13-15
# 12-14
# 4-6
# 11-13
# 2-4
# 6-8
# 12-14
# 2-4
# 10-12
# 5-7
# 3-5
# 4-6
# 12-14
# 7-9
# 5-7
# 2-4
# 7-9
# 6-8
# 9-11
# 11-13
# 8-10
# 3-5
# 2-4
# 8-10
# 1-3
# 11-13
# 7-9
# 2-4
# 3-5
# 1-3
# 2-4
# 15-17
# 14-16
# 5-7
# 8-10
# 2-4
# 4-6
# 11-13
# 5-7
# 4-6
# 5-7
# 5-7
# 4-6
# 6-8
# 2-4
# 12-14
# 8-10
# 11-13
# 7-9
# 4-6
# 6-8
# 8-10
# 2-4
# 7-9
# 14-16
# 10-12
# 2-4
# 9-11
# 6-8
# 1-3
# 4-6
# 4-6
# 3-5
# 3-5
# 4-6
# 14-16
# 9-11
# 9-11
# 6-8
# 3-5
# 9-11
# 5-7
# 8-10
# 5-7
# 9-11
# 10-12
# 10-12
# 2-4
# 3-5
# 4-6
# 4-6
# 3-5
# 3-5
# 4-6
# 5-7
# 9-11
# 10-12
# 4-6
# 9-11
# 6-8
# 10-12
# 9-11
# 3-5
# 4-6
# 4-6
# 4-6
# 8-10
# 9-11
# 4-6
# 7-9
# 7-9
# 8-10
# 3-5
# 11-13
# 10-12
# 3-5
# 4-6
# 4-6
# 4-6
# 12-14
# 4-6
# 2-4
# 3-5
# 11-13
# 3-5
# 5-7
# 13-15
# 7-9
# 5-7
# 6-8
# 6-8
# 3-5
# 5-7
# 3-5
# 8-10
# 5-7
# 1-3
# 3-5
# 7-9
# 8-10
# 3-5
# 3-5
# 4-6
# 7-9
# 3-5
# 3-5
# 3-5
# 4-6
# 10-12
# 13-15
# 3-5
# 6-8
# 4-6
# 5-7
# 4-6
# 6-8
# 12-14
# 13-15
# 2-4
# 3-5
# 4-6
# 12-14
# 4-6
# 3-5
# 11-13
# 6-8
# 4-6
# 0-2
# 8-10
# 3-5
# 6-8
# 2-4
# 3-5
# 2-4
# 2-4
# 5-7
# 5-7
# 11-13
# 5-7
# 9-11
# 6-8
# 1-3
# 6-8
# 3-5
# 6-8
# 7-9
# 10-12
# 8-10
# 9-11
# 5-7
# 10-12
# 11-13
# 7-9
# 12-14
# 7-9
# 4-6
# 10-12
# 6-8
# 4-6
# 4-6
# 3-5
# 6-8
# 9-11
# 4-6
# 6-8
# 7-9
# 12-14
# 7-9
# 11-13
# 5-7
# 4-6
# 9-11
# 8-10
# 8-10
# 2-4
# 3-5
# 2-4
# 8-10
# 13-15
# 9-11
# 10-12
# 11-13
# 3-5
# 11-13
# 8-10
# 2-4
# 7-9
# 6-8
# 8-10
# 2-4
# 6-8
# 4-6
# 10-12
# 5-7
# 2-4
# 3-5
# 2-4
# 14-16
# 6-8
# 7-9
# 10-12
# 4-6
# 9-11
# 3-5
# 7-9
# 3-5
# 5-7
# 9-11
# 6-8
# 8-10
# 1-3
# 5-7
# 4-6
# 6-8
# 4-6
# 10-12
# 3-5
# 8-10
# 10-12
# 2-4
# 6-8
# 6-8
# 11-13
# 8-10
# 8-10
# 5-7
# 3-5
# 5-7
# 10-12
# 9-11
# 6-8
# 2-4
# 11-13
# 11-13
# 7-9
# 7-9
# 11-13
# 6-8
# 14-16
# 5-7
# 7-9
# 11-13
# 8-10
# 4-6
# 4-6
# 10-12
# 9-11
# 10-12
# 4-6
# 4-6
# 5-7
# 7-9
# 11-13
# 11-13
# 4-6
# 10-12
# 1-3
# 2-4
# 6-8
# 5-7
# 2-4
# 4-6
# 7-9
# 6-8
# 11-13
# 9-11
# 4-6
# 5-7
# 5-7
# 7-9
# 3-5
# 7-9
# 4-6
# 6-8
# 3-5
# 9-11
# 2-4
# 5-7
# 6-8
# 5-7
# 3-5
# 4-6
# 6-8
# 4-6
# 3-5
# 10-12
# 7-9
# 7-9
# 5-7
# 5-7
# 10-12
# 6-8
# 3-5
# 2-4
# 11-13
# 1-3
# 12-14
# 7-9
# 7-9
# 3-5
# 2-4
# 10-12
# 8-10
# 4-6
# 3-5
# 3-5
# 2-4
# 10-12
# 4-6
# 7-9
# 5-7
# 8-10
# 2-4
# 6-8
# 12-14
# 9-11
# 4-6
# 3-5
# 1-3
# 4-6
# 3-5
# 9-11
# 3-5
# 10-12
# 1-3
# 2-4
# 12-14
# 11-13
# 4-6
# 12-14
# 13-15
# 8-10
# 3-5
# 6-8
# 12-14
# 3-5
# 2-4
# 9-11
# 4-6
# 7-9
# 5-7
# 7-9
# 12-14
# 5-7
# 11-13
# 6-8
# 7-9
# 12-14
# 4-6
# 8-10
# 4-6
# 8-10
# 5-7
# 5-7
# 9-11
# 3-5
# 6-8
# 8-10
# 7-9
# 4-6
# 3-5
# 3-5
# 8-10
# 5-7
# 7-9
# 12-14
# 2-4
# 5-7
# 8-10
# 12-14
# 4-6
# 11-13
# 8-10
# 4-6
# 9-11
# 7-9
# 7-9
# 8-10
# 3-5
# 3-5
# 5-7
# 7-9
# 10-12
# 8-10
# 6-8
# 5-7
# 4-6
# 7-9
# 3-5
# 1-3
# 12-14
# 10-12
# 5-7
# 7-9
# 5-7
# 8-10
# 2-4
# 10-12
# 8-10
# 7-9
# 9-11
# 5-7
# 7-9
# 16-18
# 6-8
# 4-6
# 3-5
# 7-9
# 9-11
# 3-5
# 11-13
# 7-9
# 11-13
# 5-7
# 4-6
# 14-16
# 2-4
# 4-6
# 9-11
# 6-8
# 9-11
# 12-14
# 7-9
# 7-9
# 11-13
# 6-8
# 5-7
# 3-5
# 4-6
# 7-9
# 5-7
# 1-3
# 9-11
# 10-12
# 2-4
# 10-12
# 4-6
# 6-8
# 5-7
# 7-9
# 10-12
# 4-6
# 5-7
# 2-4
# 4-6
# 7-9
# 10-12
# 3-5
# 1-3
# 4-6
# 4-6
# 7-9
# 3-5
# 8-10
# 6-8
# 6-8
# 4-6
# 5-7
# 3-5
# 11-13
# 8-10
# 12-14
# 4-6
# 5-7
# 6-8
# 8-10
# 6-8
# 7-9
# 6-8
# 9-11
# 7-9
# 5-7
# 7-9
# 5-7
# 5-7
# 5-7
# 5-7
# 12-14
# 1-3
# 8-10
# 11-13
# 7-9
# 3-5
# 2-4
# 12-14
# 6-8
# 12-14
# 2-4
# 4-6
# 9-11
# 10-12
# 9-11
# 2-4
# 11-13
# 3-5
# 11-13
# 6-8
# 5-7
# 9-11
# 5-7
# 7-9
# 4-6
# 2-4
# 5-7
# 9-11
# 7-9
# 2-4
# 5-7
# 4-6
# 8-10
# 2-4
# 16-18
# 6-8
# 3-5
# 2-4
# 5-7
# 2-4
# 5-7
# 5-7
# 8-10
# 8-10
# 6-8
# 6-8
# 7-9
# 7-9
# 9-11
# 4-6
# 5-7
# 8-10
# 13-15
# 15-17
# 14-16
# 9-11
# 3-5
# 3-5
# 5-7
# 4-6
# 10-12
# 3-5
# 12-14
# 8-10
# 13-15
# 4-6
# 7-9
# 3-5
# 3-5
# 2-4
# 10-12
# 5-7
# 9-11
# 3-5
# 4-6
# 2-4
# 5-7
# 9-11
# 4-6
# 6-8
# 8-10
# 4-6
# 10-12
# 7-9
# 6-8
# 5-7
# 4-6
# 1-3
# 4-6
# 13-15
# 10-12
# 5-7
# 10-12
# 8-10
# 8-10
# 12-14
# 10-12
# 9-11
# 7-9
# 6-8
# 8-10
# 12-14
# 4-6
# 3-5
# 2-4
# 4-6
# 5-7
# 5-7
# 3-5
# 2-4
# 10-12
# 5-7
# 8-10
# 8-10
# 4-6
# 9-11
# 11-13
# 1-3
# 8-10
# 7-9
# 14-16
# 3-5
# 5-7
# 5-7
# 5-7
# 5-7
# 4-6
# 3-5
# 8-10
# 4-6
# 5-7
# 5-7
# 4-6
# 12-14
# 7-9
# 2-4
# 4-6
# 8-10
# 4-6
# 5-7
# 6-8
# 5-7
# 11-13
# 8-10
# 4-6
# 4-6
# 8-10
# 5-7
# 7-9
# 4-6
# 7-9
# 3-5
# 3-5
# 6-8
# 13-15
# 8-10
# 9-11
# 11-13
# 1-3
# 5-7
# 3-5
# 10-12
# 5-7
# 12-14
# 6-8
# 8-10
# 5-7
# 12-14
# 11-13
# 5-7
# 7-9
# 11-13
# 9-11
# 10-12
# 4-6
# 12-14
# 10-12
# 6-8
# 2-4
# 3-5
# 10-12
# 10-12
# 7-9
# 1-3
# 6-8
# 11-13
# 1-3
# 7-9
# 5-7
# 5-7
# 4-6
# 8-10
# 13-15
# 3-5
# 11-13
# 12-14
# 12-14
# 5-7
# 2-4
# 7-9
# 5-7
# 7-9
# 13-15
# 11-13
# 12-14
# 11-13
# 4-6
# 3-5
# 6-8
# 8-10
# 5-7
# 7-9
# 8-10
# 2-4
# 12-14
# 12-14
# 3-5
# 3-5
# 4-6
# 8-10
# 3-5
# 9-11
# 3-5
# 5-7
# 5-7
# 1-3
# 4-6
# 6-8
# 10-12
# 7-9
# 4-6
# 14-16
# 3-5
# 5-7
# 6-8
# 3-5
# 13-15
# 3-5
# 3-5
# 2-4
# 5-7
# 6-8
# 5-7
# 4-6
# 6-8
# 12-14
# 5-7
# 9-11
# 12-14
# 6-8
# 6-8
# 5-7
# 8-10
# 15-17
# 4-6
# 7-9
# 2-4
# 4-6
# 6-8
# 5-7
# 4-6
# 6-8
# 3-5
# 12-14
# 11-13
# 2-4
# 5-7
# 4-6
# 10-12
# 6-8
# 10-12
# 8-10
# 6-8
# 4-6
# 8-10
# 3-5
# 4-6
# 1-3
# 3-5
# 15-17
# 7-9
# 11-13
# 5-7
# 4-6
# 4-6
# 10-12
# 7-9
# 11-13
# 6-8
# 5-7
# 8-10
# 9-11
# 11-13
# 1-3
# 7-9
# 10-12
# 13-15
# 7-9
# 7-9
# 2-4
# 8-10
# 2-4
# 11-13
# 3-5
# 8-10
# 10-12
# 10-12
# 6-8
# 6-8
# 4-6
# 2-4
# 5-7
# 3-5
# 7-9
# 7-9
# 3-5
# 7-9
# 4-6
# 5-7
# 15-17
# 10-12
# 14-16
# 6-8
# 2-4
# 4-6
# 8-10
# 1-3
# 4-6
# 1-3
# 8-10
# 5-7
# 9-11
# 11-13
# 6-8
# 5-7
# 5-7
# 11-13
# 3-5
# 8-10
# 7-9
# 10-12
# 16-18
# 13-15
# 1-3
# 10-12
# 8-10
# 12-14
# 9-11
# 2-4
# 12-14
# 7-9
# 1-3
# 3-5
# 14-16
# 14-16
# 1-3
# 7-9
# 5-7
# 2-4
# 6-8
# 4-6
# 6-8
# 8-10
# 8-10
# 6-8
# 3-5
# 6-8
# 14-16
# 10-12
# 10-12
# 8-10
# 10-12
# 4-6
# 9-11
# 7-9
# 10-12
# 7-9
# 6-8
# 13-15
# 8-10
# 6-8
# 6-8
# 8-10
# 3-5
# 3-5
# 7-9
# 7-9
# 10-12
# 3-5
# 11-13
# 4-6
# 3-5
# 3-5
# 2-4
# 5-7
# 6-8
# 11-13
# 3-5
# 1-3
# 1-3
# 5-7
# 5-7
# 8-10
# 2-4
# 6-8
# 5-7
# 2-4
# 5-7
# 4-6
# 6-8
# 4-6
# 7-9
# 16-18
# 9-11
# 9-11
# 4-6
# 7-9
# 7-9
# 4-6
# 7-9
# 11-13
# 4-6
# 14-16
# 5-7
# 5-7
# 9-11
# 13-15
# 8-10
# 8-10
# 4-6
# 4-6
# 6-8
# 12-14
# 7-9
# 7-9
# 8-10
# 3-5
# 12-14
# 4-6
# 6-8
# 5-7
# 7-9
# 6-8
# 4-6
# 2-4
# 7-9
# 4-6
# 4-6
# 9-11
# 12-14
# 5-7
# 3-5
# 10-12
# 4-6
# 9-11
# 10-12
# 6-8
# 7-9
# 13-15
# 12-14
# 4-6
# 11-13
# 2-4
# 6-8
# 12-14
# 2-4
# 10-12
# 5-7
# 3-5
# 4-6
# 12-14
# 7-9
# 5-7
# 2-4
# 7-9
# 6-8
# 9-11
# 11-13
# 8-10
# 3-5
# 2-4
# 8-10
# 1-3
# 11-13
# 7-9
# 2-4
# 7-9
# 3-5
# 2-4
# 1-3
# 2-4
# 15-17
# 14-16
# 5-7
# 8-10
# 2-4
# 4-6
# 11-13
# 5-7
# 4-6
# 5-7
# 5-7
# 4-6
# 6-8
# 2-4
# 12-14
# 8-10
# 3-5
# 11-13
# 7-9
# 4-6
# 4-6
# 6-8
# 8-10
# 2-4
# 7-9
# 14-16
# 10-12
# 2-4
# 9-11
# 6-8
# 1-3
# 4-6
# 4-6
# 3-5
# 3-5
# 4-6
# 14-16
# 9-11
# 9-11
# 6-8
# 3-5
# 9-11
# 5-7
# 8-10
# 5-7
# 9-11
# 10-12
# 10-12
# 2-4
# 3-5
# 4-6
# 4-6
# 3-5
# 3-5
# 4-6
# 5-7
# 9-11
# 10-12
# 4-6
# 9-11
# 6-8
# 10-12
# 9-11
# 3-5
# 4-6
# 4-6
# 4-6
# 8-10
# 9-11
# 4-6
# 7-9
# 7-9
# 8-10
# 3-5
# 11-13
# 10-12
# 3-5
# 4-6
# 4-6
# 4-6
# 12-14
# 4-6
# 2-4
# 3-5
# 11-13
# 3-5
# 5-7
# 13-15
# 7-9
# 5-7
# 6-8
# 6-8
# 3-5
# 5-7
# 2-4
# 3-5
# 8-10
# 5-7
# 1-3
# 3-5
# 7-9
# 8-10
# 3-5
# 3-5
# 4-6
# 9-11
# 7-9
# 3-5
# 3-5
# 3-5
# 4-6
# 10-12
# 13-15
# 3-5
# 6-8
# 4-6
# 5-7
# 4-6
# 6-8
# 2-4
# 12-14
# 13-15
# 2-4
# 3-5
# 4-6
# 12-14
# 4-6
# 3-5
# 11-13
# 6-8
# 4-6
# 0-2
# 8-10
# 3-5
# 6-8
# 2-4
# 3-5
# 2-4
# 2-4
# 5-7
# 5-7
# 11-13
# 5-7
# 9-11
# 6-8
# 1-3
# 6-8
# 3-5
# 6-8
# 7-9
# 10-12
# 8-10
# 9-11
# 5-7
# 10-12
# 7-9
# 11-13
# 7-9
# 12-14
# 7-9
# 4-6
# 10-12
# 6-8
# 4-6
# 4-6
# 3-5
# 6-8
# 9-11
# 4-6
# 6-8
# 7-9
# 12-14
# 7-9
# 11-13
# 5-7
# 4-6
# 9-11
# 8-10
# 8-10
# 2-4
# 3-5
# 2-4
# 8-10
# 13-15
# 9-11
# 10-12
# 11-13
# 3-5
# 11-13
# 8-10
# 2-4
# 7-9
# 6-8
# 8-10
# 2-4
# 6-8
# 6-8
# 4-6
# 10-12
# 5-7
# 2-4
# 3-5
# 2-4
# 14-16
# 6-8
# 7-9
# 10-12
# 4-6
# 9-11
# 3-5
# 7-9
# 3-5
# 5-7
# 9-11
# 6-8
# 8-10
# 1-3
# 5-7
# 4-6
# 6-8
# 4-6
# 10-12
# 3-5
# 8-10
# 10-12
# 2-4
# 6-8
# 6-8
# 11-13
# 8-10
# 8-10
# 5-7
# 3-5
# 5-7
# 10-12
# 9-11
# 9-11
# 6-8
# 2-4
# 11-13
# 11-13
# 7-9
# 7-9
# 11-13
# 6-8
# 3-5
# 14-16
# 5-7
# 7-9
# 11-13
# 8-10
# 4-6
# 7-9
# 4-6
# 10-12
# 9-11
# 10-12
# 4-6
# 4-6
# 5-7
# 7-9
# 11-13
# 11-13
# 4-6
# 10-12
# 1-3
# 2-4
# 6-8
# 5-7
# 2-4
# 4-6
# 7-9
# 6-8
# 11-13
# 9-11
# 4-6
# 5-7
# 5-7
# 7-9
# 2-4
# 3-5
# 7-9
# 4-6
# 6-8
# 3-5
# 9-11
# 2-4
# 5-7
# 6-8
# 5-7
# 3-5
# 4-6
# 6-8
# 4-6
# 3-5
# 10-12
# 7-9
# 7-9
# 5-7
# 5-7
# 10-12
# 6-8
# 3-5
# 2-4
# 11-13
# 1-3
# 12-14
# 7-9
# 7-9
# 3-5
# 2-4
# 10-12
# 8-10
# 4-6
# 3-5
# 3-5
# 2-4
# 10-12
# 4-6
# 7-9
# 5-7
# 8-10
# 2-4
# 6-8
# 12-14
# 9-11
# 4-6
# 3-5
# 1-3
# 4-6
# 3-5
# 9-11
# 3-5
# 8-10
# 10-12
# 1-3
# 2-4
# 12-14
# 11-13
# 2-4
# 4-6
# 12-14
# 13-15
# 8-10
# 3-5
# 6-8
# 12-14
# 3-5
# 2-4
# 9-11
# 4-6
# 7-9
# 5-7
# 7-9
# 12-14
# 5-7
# 11-13
# 6-8
# 7-9
# 12-14
# 4-6
# 8-10
# 1-3
# 4-6
# 8-10
# 5-7
# 5-7
# 9-11
# 3-5
# 6-8
# 8-10
# 8-10
# 7-9
# 4-6
# 3-5
# 3-5
# 8-10
# 5-7
# 7-9
# 12-14
# 2-4
# 5-7
# 8-10
# 12-14
# 4-6
# 11-13
# 8-10
# 4-6
# 9-11
# 7-9
# 7-9
# 8-10
# 3-5
# 3-5
# 5-7
# 7-9
# 7-9
# 10-12
# 8-10
# 6-8
# 5-7
# 4-6
# 7-9
# 3-5
# 1-3
# 12-14
# 10-12
# 3-5
# 5-7
# 7-9
# 5-7
# 8-10
# 2-4
# 10-12
# 8-10
# 7-9
# 9-11
# 5-7
# 7-9
# 16-18
# 6-8
# 4-6
# 3-5
# 5-7
# 9-11
# 7-9
# 9-11
# 3-5
# 11-13
# 7-9
# 11-13
# 5-7
# 4-6
# 14-16
# 2-4
# 4-6
# 9-11
# 6-8
# 9-11
# 12-14
# 7-9
# 7-9
# 11-13
# 6-8
# 5-7
# 3-5
# 4-6
# 7-9
# 5-7
# 1-3
# 9-11
# 10-12
# 2-4
# 10-12
# 4-6
# 6-8
# 5-7
# 7-9
# 10-12
# 4-6
# 5-7
# 2-4
# 4-6
# 7-9
# 10-12
# 3-5
# 1-3
# 4-6
# 4-6
# 7-9
# 3-5
# 8-10
# 6-8
# 6-8
# 4-6
# 5-7
# 1-3
# 3-5
# 11-13
# 8-10
# 12-14
# 4-6
# 5-7
# 6-8
# 8-10
# 6-8
# 7-9
# 6-8
# 9-11
# 2-4
# 7-9
# 7-9
# 5-7
# 7-9
# 5-7
# 5-7
# 5-7
# 1-3
# 5-7
# 12-14
# 1-3
# 8-10
# 11-13
# 7-9
# 3-5
# 2-4
# 12-14
# 6-8
# 12-14
# 2-4
# 4-6
# 9-11
# 3-5
# 10-12
# 9-11
# 2-4
# 11-13
# 3-5
# 11-13
# 6-8
# 5-7
# 9-11
# 5-7
# 7-9
# 4-6
# 2-4
# 5-7
# 9-11
# 7-9
# 2-4
# 5-7
# 4-6
# 8-10
# 2-4
# 16-18
# 6-8
# 7-9
# 3-5
# 2-4
# 5-7
# 5-7
# 2-4
# 5-7
# 5-7
# 8-10
# 8-10
# 6-8
# 6-8
# 7-9
# 7-9
# 9-11
# 4-6
# 5-7
# 8-10
# 13-15
# 15-17
# 14-16
# 9-11
# 3-5
# 3-5
# 5-7
# 7-9
# 6-8
# 4-6
# 10-12
# 3-5
# 12-14
# 8-10
# 13-15
# 4-6
# 7-9
# 3-5
# 3-5
# 2-4
# 10-12
# 5-7
# 9-11
# 3-5
# 4-6

# %% [markdown]
# # Task 1.3 - Entity Linking

# %%
def perfect_match(r1, r2):
    name1 = basicCleaningPipeline(r1.name_string)
    name2 = basicCleaningPipeline(r2.name_string)

    if(name1 == name2):
        return 1
    
    fuzzy_thresh = 0.85

    name_l_score = round(rltk.levenshtein_similarity(name1, name2), 2)

    if(name_l_score > fuzzy_thresh):
        return 1
    
    return 0

# %%
# Rule based method

MY_TRESH = 0.85 

def rule_based_method(r1, r2):
    jaccard_score = jaccard(r1, r2)
    perfect_match_score = perfect_match(r1, r2)
    
    total = 0.20 * jaccard_score + \
            0.80 * perfect_match_score
    
    # return two values: boolean if they match or not, float to determine confidence
    return round(total, 2) > MY_TRESH, total

# %% [markdown]
# # Task 1.4 - Record Linkage

# %%
"""
Header:
Name,Ash,Calcium,Calories,Carbohydrate,Copper,Fat,Iron,Magnesium,Potassium,Protein,Saturated_fatty_acids,Sodium,Vitamin_A_RAE,Vitamin_B6,Water,Zinc,Fatty_acids_total_trans,Manganese,Vitamin_D,Glycemic_Load,Completeness_Score,Amino_Acid_Score,Category,Sub_Category

From 18 mins to 2 mins for 10Kx10K records with blocking. That is ~10 times faster.
"""

true_predictions = list()

with open('merged_dataset.csv', mode='w') as file:
    writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    candidate_pairs = rltk.get_record_pairs(ds1, ds2, block=block)

    hit_count = 0

    for r1, r2 in candidate_pairs:
        result, confidence = rule_based_method(r1, r2)
        if(result):
            hit_count += 1
            true_predictions.append((r1.id, r2.id))
            print(r1.name_string, "===", r2.name_string, confidence)
            writer.writerow((r2.id, r1.Ash, r1.Calcium, r1.Calories, r1.Carbohydrate, r1.Copper, r1.Fat, r1.Iron, r1.Magnesium, r1.Potassium, r1.Protein, r1.Saturated_fatty_acids, r1.Sodium, r1.Vitamin_A_RAE, r1.Vitamin_B6, r1.Water, r1.Zinc, r1.Fatty_acids_total_trans, r1.Manganese, r1.Vitamin_D, r2.Glycemic_Load, r2.Completeness_Score, r2.Amino_Acid_Score, r1.Category, r1.Sub_Category))

print("Hits:", hit_count)
# Out:
# Broccoli, cooked, chinese === broccoli cooked chinese 0.8800000000000001
# Broccoli, raw, chinese === broccoli raw chinese 0.8800000000000001
# Catsup, low sodium === catsup low sodium 0.8800000000000001
# Babyfood, pear, juice === babyfood pear juice 0.8800000000000001
# DENNY'S, chicken strips === dennys chicken strips 0.8571428571428572
# Bread, toasted, egg === bread toasted egg 0.8800000000000001
# Chrysanthemum, raw, garland === chrysanthemum raw garland 0.8800000000000001
# Onions, raw, welsh === onions raw welsh 0.8800000000000001
# Whey, fluid, sweet === whey fluid sweet 0.8800000000000001
# Egg, dried, white === egg dried white 0.8800000000000001
# Bratwurst, cooked, veal === bratwurst cooked veal 0.8800000000000001
# Broccoli, raw, leaves === broccoli raw leaves 0.8800000000000001
# Whey, fluid, acid === whey fluid acid 0.8800000000000001
# Ostrich, cooked, oyster === ostrich cooked oyster 0.8800000000000001
# Egg substitute, powder === egg substitute powder 0.8800000000000001
# Ice cream sandwich === ice cream sandwich 0.9
# Salami, turkey, cooked === salami turkey cooked 0.8800000000000001
# Seaweed, raw, laver === seaweed raw laver 0.8800000000000001
# Seaweed, dried, spirulina === seaweed dried spirulina 0.8800000000000001
# Fiddlehead ferns, raw === fiddlehead ferns raw 0.8800000000000001
# Sweetener, agave, syrup === sweetener agave syrup 0.8800000000000001
# Peppers, dried, ancho === peppers dried ancho 0.8800000000000001
# Seaweed, raw, agar === seaweed raw agar 0.8800000000000001
# Crackers, water biscuits === crackers water biscuits 0.8800000000000001
# Potatoes, skin, raw === potatoes skin raw 0.8800000000000001
# Danish pastry, cheese === danish pastry cheese 0.8800000000000001
# Onions, dehydrated flakes === onions dehydrated flakes 0.8800000000000001
# Malabar spinach, cooked === malabar spinach cooked 0.8800000000000001
# Fat, beef tallow === fat beef tallow 0.8800000000000001
# Soybeans, raw, green === soybeans raw green 0.8800000000000001
# Roast beef spread === roast beef spread 0.9
# Babyfood, apple, juice === babyfood apple juice 0.8800000000000001
# Chicory, raw, witloof === chicory raw witloof 0.8800000000000001
# Canadian bacon, unprepared === canadian bacon unprepared 0.8800000000000001
# Ostrich, raw, tenderloin === ostrich raw tenderloin 0.8800000000000001
# Seaweed, dried, agar === seaweed dried agar 0.8800000000000001
# Seaweed, raw, kelp === seaweed raw kelp 0.8800000000000001
# Olive loaf, pork === olive loaf pork 0.8800000000000001
# Brussels sprouts, raw === brussels sprouts raw 0.8800000000000001
# Candies, sesame crunch === candies sesame crunch 0.8800000000000001
# Bologna, pork, chicken === bologna pork chicken 0.8800000000000001
# Cabbage, cooked, napa === cabbage cooked napa 0.8800000000000001
# Vinespinach, raw, (basella) === vinespinach raw basella 0.8571428571428572
# Mushrooms, grilled, portabella === mushrooms grilled portabella 0.8800000000000001
# Chicken, boiled, feet === chicken boiled feet 0.8800000000000001
# Beverages, orange, carbonated === beverages orange carbonated 0.8800000000000001
# Tostada shells, corn === tostada shells corn 0.8800000000000001
# Cabbage, salted, mustard === cabbage salted mustard 0.8800000000000001
# Restaurant, bunuelos (fried yeast bread), Latino === restaurant bunuelos fried yeast bread latino 0.8727272727272728
# Goose, raw, meat and skin, domesticated === duck raw meat and skin domesticated 0.925
# Goose, raw, meat and skin, domesticated === goose raw meat and skin domesticated 0.925
# Ham and cheese loaf or roll === ham and cheese loaf or roll 0.942857142857143
# Beverages, sugar free, AMP, Energy drink === beverages sugar free amp energy drink 0.8600000000000001
# Babyfood, strained, with egg yolks, cereal === babyfood strained with egg yolks cereal 0.925
# Ice creams, chocolate, low carbohydrate, regular === ice creams chocolate low carbohydrate regular 0.925
# Crackers, low salt, regular, standard snack-type === crackers low salt regular standard snacktype 0.8727272727272728
# Babyfood, strained, corn and sweet potatoes === babyfood strained corn and sweet potatoes 0.925
# .75oz doritos nacho by Frito Lay === 75oz doritos nacho by frito lay 0.888888888888889
# Borage, with salt, drained, boiled, cooked === kohlrabi with salt drained boiled cooked 0.925
# Borage, with salt, drained, boiled, cooked === borage with salt drained boiled cooked 0.925
# Pancakes, prepared, incomplete, dry mix, whole-wheat === pancakes prepared incomplete dry mix wholewheat 0.8727272727272728
# Doughnuts, sugared or glazed, chocolate, cake-type === doughnuts sugared or glazed chocolate caketype 0.8727272727272728
# Babyfood, strained, applesauce and pineapple, fruit === babyfood strained applesauce and pineapple fruit 0.925
# Candies, soft fruit and nut squares === candies soft fruit and nut squares 0.925
# Turnip greens, solids and liquids, canned === turnip greens solids and liquids canned 0.925
# Candies, not chocolate covered, coconut bar === candies not chocolate covered coconut bar 0.925
# Beverages, diet, lemon, decaffeinated, instant, tea === beverages diet lemon decaffeinated instant tea 0.925
# Babyfood, junior, apple and blueberry, fruit === babyfood junior apple and blueberry fruit 0.925
# Pancakes, incomplete, dry mix, whole wheat === pancakes incomplete dry mix whole wheat 0.925
# Beverages, No pulp, light, Orange juice === beverages no pulp light orange juice 0.8600000000000001
# Kohlrabi, with salt, drained, boiled, cooked === kohlrabi with salt drained boiled cooked 0.925
# Kohlrabi, with salt, drained, boiled, cooked === kohlrabi without salt drained boiled cooked 0.888888888888889
# Kohlrabi, with salt, drained, boiled, cooked === borage with salt drained boiled cooked 0.925
# Chicken breast tenders, microwaved, cooked, breaded === chicken breast tenders microwaved cooked breaded 0.925
# Kohlrabi, without salt, drained, boiled, cooked === kale without salt drained boiled cooked 0.925
# Kohlrabi, without salt, drained, boiled, cooked === kohlrabi with salt drained boiled cooked 0.888888888888889
# Kohlrabi, without salt, drained, boiled, cooked === kohlrabi without salt drained boiled cooked 0.925
# Turkey, roasted, cooked, dark meat, whole === turkey roasted cooked dark meat whole 0.925
# Cookies, baked, refrigerated dough, chocolate chip === cookies baked refrigerated dough chocolate chip 0.925
# Cookies, baked, refrigerated dough, peanut butter === cookies baked refrigerated dough peanut butter 0.925
# Tomato products, with onions, sauce, canned === tomato products with onions sauce canned 0.925
# Babyfood, toddler, beef with vegetables, meat === babyfood toddler beef with vegetables meat 0.925
# Alcoholic beverage, 63 proof, coffee, liqueur === alcoholic beverage 63 proof coffee liqueur 0.925
# Kale, without salt, drained, boiled, cooked === kale without salt drained boiled cooked 0.925
# Kale, without salt, drained, boiled, cooked === kohlrabi without salt drained boiled cooked 0.925
# Kale, without salt, drained, boiled, cooked === dock without salt drained boiled cooked 0.925
# Babyfood, Banana with orange medley, GERBER === babyfood banana with orange medley gerber 0.8600000000000001
# Bread, salvadoran sweet cheese (quesadilla salvadorena) === bread salvadoran sweet cheese quesadilla salvadorena 0.9
# APPLEBEE'S, from kids' menu, chicken tenders === applebees from kids menu chicken tenders 0.9
# Yogurt, CHOBANI, lemon blend, nonfat, Greek === yogurt chobani lemon blend nonfat greek 0.8600000000000001
# Frozen yogurts, flavors other than chocolate === frozen yogurts flavors other than chocolate 0.925
# Beans, solids and liquids, canned, shellie === beans solids and liquids canned shellie 0.925
# Salad dressing, regular, commercial, peppercorn dressing === salad dressing regular commercial peppercorn dressing 0.9142857142857144
# Squash, canned, italian style, zucchini, summer === squash canned italian style zucchini summer 0.925
# Babyfood, strained, vegetables and turkey, dinner === babyfood strained vegetables and turkey dinner 0.925
# Mung beans, raw, sprouted, mature seeds === mung beans raw sprouted mature seeds 0.925
# Turkey, pan-broiled crumbles, fat free, ground === turkey panbroiled crumbles fat free ground 0.8727272727272728
# Restaurant, spaghetti and meatballs, family style === restaurant spaghetti and meatballs family style 0.925
# Cheese, reduced fat, dry grated, parmesan === cheese reduced fat dry grated parmesan 0.925
# Beverages, sweetened, lemon, ready-to-drink, black, tea === beverages sweetened lemon readytodrink black tea 0.8666666666666667
# Pie, prepared from recipe, vanilla cream === pie prepared from recipe vanilla cream 0.925
# Wonton wrappers (includes egg roll wrappers) === wonton wrappers includes egg roll wrappers 0.9
# Sausage, hot, beef with chicken, Polish === sausage hot beef with chicken polish 0.888888888888889
# Alcoholic Beverage, Burgundy, red, table, wine === alcoholic beverage burgundy red table wine 0.8600000000000001
# Tomato juice, without salt added, canned === tomato juice without salt added canned 0.925
# Alcoholic Beverage, Mouvedre, red, table, wine === alcoholic beverage mouvedre red table wine 0.8600000000000001
# Alcoholic beverage, Chardonnay, white, table, wine === alcoholic beverage chardonnay white table wine 0.888888888888889
# Cheese, nonfat or fat free, cheddar === cheese nonfat or fat free cheddar 0.925
# Tomato products, spanish style, sauce, canned === tomato products spanish style sauce canned 0.925
# Salad dressing, reduced fat, ranch dressing === salad dressing reduced fat ranch dressing 0.9142857142857144
# Beverages, sugar free, ROCKSTAR, Energy drink === beverages sugar free rockstar energy drink 0.8600000000000001
# Cookies, special dietary, commercially prepared, oatmeal === cookies special dietary commercially prepared oatmeal 0.925
# Babyfood, dry, with honey, oatmeal, cereal === babyfood dry with honey oatmeal cereal 0.925
# Pancakes, prepared, complete, dry mix, plain === pancakes prepared complete dry mix plain 0.925
# Puddings, instant, dry mix, coconut cream === puddings instant dry mix coconut cream 0.925
# Candies, milk chocolate coated coffee beans === candies milk chocolate coated coffee beans 0.925
# Cookies, made with rice cereal, chocolate === cookies made with rice cereal chocolate 0.925
# Waffles, toasted, ready -to-heat, frozen, plain === waffles toasted ready toheat frozen plain 0.8727272727272728
# Beverages, canned, Clam and tomato juice === beverages canned clam and tomato juice 0.888888888888889
# Cookies, special dietary, peanut butter sandwich === cookies special dietary peanut butter sandwich 0.925
# Leeks, raw, (bulb and lower leaf-portion) === leeks raw bulb and lower leafportion 0.8615384615384616
# Butterbur, with salt, drained, boiled, cooked === butterbur with salt drained boiled cooked 0.925
# Egg, pasteurized, salted, frozen, raw, whole === egg pasteurized salted frozen raw whole 0.925
# Cake, dry mix, enriched, white, pudding-type === cake dry mix enriched white puddingtype 0.8727272727272728
# Cauliflower, with salt, drained, boiled, cooked === cauliflower with salt drained boiled cooked 0.925
# Babyfood, junior, cherry vanilla pudding, dessert === babyfood junior cherry vanilla pudding dessert 0.925
# Duck, raw, meat and skin, domesticated === duck raw meat and skin domesticated 0.925
# Duck, raw, meat and skin, domesticated === goose raw meat and skin domesticated 0.925
# Dock, without salt, drained, boiled, cooked === kale without salt drained boiled cooked 0.925
# Dock, without salt, drained, boiled, cooked === dock without salt drained boiled cooked 0.925
# Doughnuts, sugared or glazed, plain, cake-type === doughnuts sugared or glazed plain caketype 0.8727272727272728
# Sesbania flower, with salt, steamed, cooked === sesbania flower with salt steamed cooked 0.925
# Sesbania flower, with salt, steamed, cooked === sesbania flower without salt steamed cooked 0.888888888888889
# Potatoes, unprepared, dry mix, au gratin === potatoes unprepared dry mix au gratin 0.925
# Bologna, low fat, beef and pork === bologna low fat beef and pork 0.925
# Sesbania flower, without salt, steamed, cooked === sesbania flower with salt steamed cooked 0.888888888888889
# Sesbania flower, without salt, steamed, cooked === sesbania flower without salt steamed cooked 0.925
# Babyfood, fruit filling, fortified cereal bar === babyfood fruit filling fortified cereal bar 0.925
# Babyfood, junior, turkey and rice, dinner === babyfood junior turkey and rice dinner 0.925
# Turnip greens and turnips, unprepared, frozen === turnip greens and turnips unprepared frozen 0.925
# Beets, solids and liquids, canned, pickled === beets solids and liquids canned pickled 0.925
# Shortening frying (heavy duty), palm (hydrogenated) === shortening frying heavy duty palm hydrogenated 0.9
# .50oz lay's regular by Frito Lay === 50oz lays regular by frito lay 0.8727272727272728
# Salad dressing, reduced calorie, italian dressing === salad dressing reduced calorie italian dressing 0.9142857142857144
# OLIVE GARDEN, chicken parmigiana without pasta === olive garden chicken parmigiana without pasta 0.888888888888889
# Crackers, egg and onion, matzo === crackers egg and onion matzo 0.9142857142857144
# Potatoes, with salt, flesh, baked === potatoes with salt flesh baked 0.9142857142857144
# Chicken, pan-browned, cooked, crumbles, ground === chicken panbrowned cooked crumbles ground 0.8600000000000001
# Duck, raw, meat only, domesticated === duck raw meat only domesticated 0.9142857142857144
# Candies, milk chocolate coated raisins === candies milk chocolate coated raisins 0.9142857142857144
# Cheese, part skim milk, ricotta === cheese part skim milk ricotta 0.9142857142857144
# Babyfood, apple and grape, juice === babyfood apple and prune juice 0.875
# Babyfood, apple and grape, juice === babyfood apple and grape juice 0.9142857142857144
# Pie crust, dry mix, standard-type === pie crust dry mix standardtype 0.8600000000000001
# Restaurant, hash browns, family style === restaurant hash browns family style 0.9142857142857144
# Alcoholic beverage, canned, whiskey sour === alcoholic beverage canned whiskey sour 0.9142857142857144
# Pepperoni, sliced, beef and pork === pepperoni sliced beef and pork 0.9142857142857144
# Turkey, raw, all classes, gizzard === turkey raw all classes gizzard 0.9142857142857144
# English muffins, whole grain white === english muffins whole grain white 0.9142857142857144
# Leavening agents, compressed, baker's, yeast === leavening agents compressed bakers yeast 0.8600000000000001
# Babyfood, toddler, macaroni and cheese === babyfood toddler macaroni and cheese 0.9142857142857144
# Sweeteners, packets, EQUAL, aspartame, tabletop === sweeteners packets equal aspartame tabletop 0.875
# Babyfood, strained, chicken noodle, dinner === babyfood strained chicken noodle dinner 0.9142857142857144
# Alcoholic beverage, canned, tequila sunrise === alcoholic beverage canned tequila sunrise 0.9142857142857144
# Candies, with peanut butter, honey-combed === candies with peanut butter honeycombed 0.8600000000000001
# Beverages, Protein powder whey based === beverages protein powder whey based 0.875
# Taro shoots, without salt, cooked === taro shoots without salt cooked 0.9142857142857144
# Puddings, instant, dry mix, vanilla === puddings instant dry mix vanilla 0.9142857142857144
# Babyfood, sweet potatoes strained, vegetables === babyfood sweet potatoes strained vegetables 0.9142857142857144
# Lima beans, raw, immature seeds === lima beans raw immature seeds 0.9142857142857144
# Oil, salad or cooking, soybean === oil salad or cooking soybean 0.9142857142857144
# Leavening agents, low-sodium, baking powder === leavening agents lowsodium baking powder 0.8600000000000001
# Babyfood, apple and prune, juice === babyfood apple and prune juice 0.9142857142857144
# Babyfood, apple and prune, juice === babyfood apple and grape juice 0.875
# Emu, broiled, cooked, top loin === emu broiled cooked top loin 0.9142857142857144
# Restaurant, prepared, beef, empanadas, Latino === restaurant prepared beef empanadas latino 0.875
# Babyfood, orange and apple, juice === babyfood orange and pineapple juice 0.875
# Babyfood, orange and apple, juice === babyfood orange and apple juice 0.9142857142857144
# Bread, toasted, commercially prepared, white === bread toasted commercially prepared white 0.9142857142857144
# Lemonade, prepared with water, powder === lemonade prepared with water powder 0.9142857142857144
# Oil, (approx. 65%), linoleic, sunflower === oil approx 65 linoleic sunflower 0.8727272727272728
# Succotash, raw, (corn and limas) === succotash raw corn and limas 0.888888888888889
# Cream, pressurized, cream topping, whipped === cream pressurized cream topping whipped 0.9333333333333333
# Beverages, breakfast blend, brewed, coffee === beverages breakfast blend brewed coffee 0.9142857142857144
# Peas and onions, unprepared, frozen === peas and onions unprepared frozen 0.9142857142857144
# Alcoholic beverage, all, regular, beer === alcoholic beverage all regular beer 0.9142857142857144
# Lettuce, raw, cos or romaine === lettuce raw cos or romaine 0.9142857142857144
# Turkey, raw, heart, all classes === turkey raw heart all classes 0.9142857142857144
# Ice cream, chocolate, soft serve === ice cream chocolate soft serve 0.9142857142857144
# Emu, broiled, cooked, inside drums === emu broiled cooked inside drums 0.9142857142857144
# Alcoholic beverage, dry, dessert, wine === alcoholic beverage dry dessert wine 0.9142857142857144
# Salami, beef and pork, cooked === salami beef and pork cooked 0.9142857142857144
# Babyfood, junior, meat sticks, meat === babyfood junior meat sticks meat 0.9
# Babyfood, junior, green beans, vegetables === babyfood junior green beans vegetables 0.9142857142857144
# Quail, raw, meat only, breast === quail raw meat only breast 0.9142857142857144
# Egg, pasteurized, frozen, raw, whole === egg pasteurized frozen raw whole 0.9142857142857144
# Cake, prepared from recipe, sponge === cake prepared from recipe sponge 0.9142857142857144
# Restaurant, lasagna with meat, Italian === restaurant lasagna with meat italian 0.875
# Beef, jellied, luncheon meat, cured === beef jellied luncheon meat cured 0.9142857142857144
# Beverages, Whey protein powder isolate === beverages whey protein powder isolate 0.875
# Cake, sponge, creme-filled, snack cakes === cake sponge cremefilled snack cakes 0.8600000000000001
# Potatoes, home-prepared with butter, scalloped === potatoes homeprepared with butter scalloped 0.8600000000000001
# Babyfood, strained, green beans, vegetables === babyfood strained green beans vegetables 0.9142857142857144
# Babyfood, strained, tutti frutti, fruit === babyfood strained tutti frutti fruit 0.9142857142857144
# Restaurant, beef and vegetables, Chinese === restaurant beef and vegetables chinese 0.875
# Alcoholic beverage, canned, pina colada === alcoholic beverage canned pina colada 0.9142857142857144
# Squab, raw, meat only, (pigeon) === squab raw meat only pigeon 0.888888888888889
# Cookies, higher fat, vanilla wafers === cookies higher fat vanilla wafers 0.9142857142857144
# Crackers, low sodium, toast thins === crackers low sodium toast thins 0.9142857142857144
# Babyfood, strained, apple yogurt dessert === babyfood strained apple yogurt dessert 0.9142857142857144
# Sweeteners, SPLENDA packets, sucralose, tabletop === sweeteners splenda packets sucralose tabletop 0.875
# Turkey sticks, fried, battered, breaded === turkey sticks fried battered breaded 0.9142857142857144
# Candies, with almonds, milk chocolate === candies with almonds milk chocolate 0.9142857142857144
# Babyfood, orange and pineapple, juice === babyfood orange and pineapple juice 0.9142857142857144
# Babyfood, orange and pineapple, juice === babyfood orange and apple juice 0.875
# Salad dressing, regular, caesar dressing === salad dressing regular caesar dressing 0.9
# Syrups, reduced-calorie, pancake, table blends === syrups reducedcalorie pancake table blends 0.8600000000000001
# Turkey, raw, light meat, whole === turkey raw light meat whole 0.9142857142857144
# Beverages, regular, brewed, green, tea === beverages regular brewed green tea 0.9142857142857144
# Beverages, strawberry, fast food, shake === beverages strawberry fast food shake 0.9142857142857144
# Potatoes, unprepared, dry mix, scalloped === potatoes unprepared dry mix scalloped 0.9142857142857144
# Cookies, regular, dry mix, brownies === cookies regular dry mix brownies 0.9142857142857144
# Babyfood, strained, carrots and beef === babyfood strained carrots and beef 0.9142857142857144
# Stew, squash (Navajo), corn, mutton === stew squash navajo corn mutton 0.8600000000000001
# Frostings, dry mix, creamy, vanilla === frostings dry mix creamy vanilla 0.9142857142857144
# Babyfood, strained, banana no tapioca === babyfood strained banana no tapioca 0.9142857142857144
# Oil, salad or cooking, olive === oil salad or cooking olive 0.9142857142857144
# Sweeteners, brown, granulated, sugar substitute === sweeteners brown granulated sugar substitute 0.9142857142857144
# Pork, unheated, patties, ham, cured === pork unheated patties ham cured 0.9142857142857144
# Cheese, with fruit, creamed, cottage === cheese with fruit creamed cottage 0.9142857142857144
# Peppers, raw, red, hot chili === peppers raw red hot chili 0.9142857142857144
# Beverages, bottled, cranberry-apple juice drink === beverages bottled cranberryapple juice drink 0.8600000000000001
# Puddings, regular, dry mix, lemon === puddings regular dry mix lemon 0.9142857142857144
# Cookies, soft-type, commercially prepared, oatmeal === cookies softtype commercially prepared oatmeal 0.8600000000000001
# Cheese food, American, cold pack === cheese food american cold pack 0.875
# Taro, with salt, cooked, tahitian === taro with salt cooked tahitian 0.9142857142857144
# Cranberry juice cocktail, frozen concentrate === cranberry juice cocktail frozen concentrate 0.9142857142857144
# Pumpkin leaves, with salt, drained, boiled, cooked === pumpkin leaves with salt drained boiled cooked 0.9333333333333333
# Squash, unprepared, frozen, crookneck and straightneck, summer === squash unprepared frozen crookneck and straightneck summer 0.9333333333333333
# Canada Goose, raw, skinless, breast meat only === canada goose raw skinless breast meat only 0.9
# Beverages, decaffeinated, ready to drink, black, tea === beverages decaffeinated ready to drink black tea 0.9333333333333333
# Pork, raw or unheated, breakfast strips, cured === pork raw or unheated breakfast strips cured 0.9333333333333333
# Salad dressing, without salt, soybean oil, mayonnaise === salad dressing without salt soybean oil mayonnaise 0.9333333333333333
# Bread, toasted (includes sourdough), french or vienna === bread toasted includes sourdough french or vienna 0.9090909090909092
# Beverages, frozen concentrate, citrus fruit juice drink === beverages frozen concentrate citrus fruit juice drink 0.9333333333333333
# Whale, subcutaneous fat (blubber) (Alaska Native), bowhead === whale subcutaneous fat blubber alaska native bowhead 0.8615384615384616
# Babyfood, finger snacks cereal fortified, baked product === babyfood finger snacks cereal fortified baked product 0.9333333333333333
# Sweet rolls, refrigerated dough with frosting, cinnamon === sweet rolls refrigerated dough with frosting cinnamon 0.9333333333333333
# Beverages, prepared with water, powder, lemonade-flavor drink === beverages prepared with water powder lemonadeflavor drink 0.8833333333333334
# Carrots, with salt, drained, boiled, cooked, frozen === kale with salt drained boiled cooked frozen 0.9333333333333333
# Carrots, with salt, drained, boiled, cooked, frozen === carrots with salt drained boiled cooked frozen 0.9333333333333333
# Beans, unprepared, all styles, frozen, yellow, snap === beans unprepared all styles frozen yellow snap 0.9333333333333333
# Cookies, regular, sugar wafers with creme filling === cookies regular sugar wafers with creme filling 0.9333333333333333
# Mushroom, raw, exposed to ultraviolet light, white === mushroom raw exposed to ultraviolet light white 0.9333333333333333
# Frozen novelties, prepackaged, sundae, ice cream type === frozen novelties prepackaged sundae ice cream type 0.9333333333333333
# Turkey, raw, meat only, thigh, retail parts === turkey raw meat only wing retail parts 0.9
# Turkey, raw, meat only, thigh, retail parts === turkey raw meat only thigh retail parts 0.9333333333333333
# Pickles, sweet, with cauliflower onion mustard, chowchow === pickles sweet with cauliflower onion mustard chowchow 0.9333333333333333
# Tomato products, without salt added, puree, canned === tomato products without salt added puree canned 0.9333333333333333
# Turkey, simmered, cooked, meat only, neck, whole === turkey simmered cooked meat only neck whole 0.9333333333333333
# Peas, with salt, drained, boiled, cooked, edible-podded === peas with salt drained boiled cooked ediblepodded 0.8833333333333334
# Potatoes, no salt added, drained solids, canned === potatoes no salt added drained solids canned 0.9333333333333333
# Cookies, with creme filling, vanilla sandwich, gluten-free === cookies with creme filling vanilla sandwich glutenfree 0.8833333333333334
# Sweet Potatoes, unprepared, frozen, crosscut, french fried === sweet potatoes unprepared frozen crosscut french fried 0.9
# Turkey, raw, skin (light and dark), whole === turkey raw skin light and dark whole 0.9090909090909092
# Crackers, with cheese filling, sandwich, standard snack-type === crackers with cheese filling sandwich standard snacktype 0.8833333333333334
# Turkey, raw, meat only, wing, retail parts === turkey raw meat only wing retail parts 0.9333333333333333
# Turkey, raw, meat only, wing, retail parts === turkey raw meat only thigh retail parts 0.9
# Kale, with salt, drained, boiled, cooked, frozen === kale with salt drained boiled cooked frozen 0.9333333333333333
# Kale, with salt, drained, boiled, cooked, frozen === carrots with salt drained boiled cooked frozen 0.9333333333333333
# Kale, with salt, drained, boiled, cooked, frozen === kale without salt drained boiled cooked frozen 0.9
# Ginger root, with artificial sweetener, canned, pickled === ginger root with artificial sweetener canned pickled 0.9333333333333333
# Lotus root, without salt, drained, boiled, cooked === lotus root without salt drained boiled cooked 0.9333333333333333
# CARRABBA'S ITALIAN GRILL, spaghetti with pomodoro sauce === carrabbas italian grill spaghetti with pomodoro sauce 0.8615384615384616
# Fish, kippered (Alaska Native), (sockeye), red, salmon === fish kippered alaska native sockeye red salmon 0.8615384615384616
# Cauliflower, with salt, drained, boiled, cooked, frozen === cauliflower with salt drained boiled cooked frozen 0.9333333333333333
# Bread, commercially prepared, plain, chapati or roti === bread commercially prepared plain chapati or roti 0.9333333333333333
# Doritos cool ranch 8z by Frito Lay === doritos cool ranch 8z by frito lay 0.8800000000000001
# Tortillas, shelf stable, flour, ready-to-bake or -fry === tortillas shelf stable flour readytobake or fry 0.8769230769230769
# Beverages, reduced calorie, with whitener, instant, coffee === beverages reduced calorie with whitener instant coffee 0.9333333333333333
# CARRABBA'S ITALIAN GRILL, spaghetti with meat sauce === carrabbas italian grill spaghetti with meat sauce 0.8615384615384616
# Cookies, regular, with creme filling, chocolate sandwich === cookies regular with creme filling chocolate sandwich 0.9333333333333333
# Pork, unheated, boneless, separable fat, ham, cured === pork unheated boneless separable fat ham cured 0.9333333333333333
# Oscar Mayer, Ham (chopped with natural juice) === oscar mayer ham chopped with natural juice 0.8615384615384616
# Ice creams, no sugar added, light, vanilla === ice creams no sugar added light vanilla 0.9333333333333333
# Asparagus, without salt, drained, boiled, cooked, frozen === okra without salt drained boiled cooked frozen 0.9333333333333333
# Asparagus, without salt, drained, boiled, cooked, frozen === asparagus without salt drained boiled cooked frozen 0.9333333333333333
# Fritos regular .75 ounce by Frito Lay === fritos regular 75 ounce by frito lay 0.8727272727272728
# Peas and onions, solids and liquids, canned === peas and onions solids and liquids canned 0.925
# Babyfood, prepared with whole milk, oatmeal, cereal === babyfood prepared with whole milk rice cereal 0.9
# Babyfood, prepared with whole milk, oatmeal, cereal === babyfood prepared with whole milk oatmeal cereal 0.9333333333333333
# Kale, without salt, drained, boiled, cooked, frozen === kale with salt drained boiled cooked frozen 0.9
# Kale, without salt, drained, boiled, cooked, frozen === kale without salt drained boiled cooked frozen 0.9333333333333333
# Kale, without salt, drained, boiled, cooked, frozen === okra without salt drained boiled cooked frozen 0.9333333333333333
# Chicken, raw, meat only, light meat, stewing === chicken raw meat only light meat stewing 0.925
# Amaranth leaves, with salt, drained, boiled, cooked === amaranth leaves with salt drained boiled cooked 0.9333333333333333
# 2.87oz fritos chili cheese by Frito Lay === 287oz fritos chili cheese by frito lay 0.8666666666666667
# Beverages, canned, pineapple and grapefruit juice drink === beverages canned pineapple and grapefruit juice drink 0.9333333333333333
# Caribou, raw (Alaska Native), hind quarter meat === caribou raw alaska native hind quarter meat 0.8615384615384616
# Alcoholic beverage, late harvest, white, table, wine === alcoholic beverage late harvest white table wine 0.9333333333333333
# Chicken, meat only, wing, BBQ, rotisserie, broiler === chicken meat only wing bbq rotisserie broiler 0.9
# Sausage, reduced sodium, and beef, turkey, pork === sausage reduced sodium and beef turkey pork 0.9333333333333333
# Egg, glucose reduced, stabilized, flakes, dried, white === egg glucose reduced stabilized flakes dried white 0.9333333333333333
# Yogurt, CHOBANI, strawberry banana, 2% fat, Greek === yogurt chobani strawberry banana 2 fat greek 0.8666666666666667
# Margarine-like, with salt, tub, vegetable oil-butter spread === margarinelike with salt tub vegetable oilbutter spread 0.8769230769230769
# Babyfood, prepared with whole milk, rice, cereal === babyfood prepared with whole milk rice cereal 0.9333333333333333
# Babyfood, prepared with whole milk, rice, cereal === babyfood prepared with whole milk oatmeal cereal 0.9
# Mushrooms, grilled, exposed to ultraviolet light, portabella === mushrooms grilled exposed to ultraviolet light portabella 0.9333333333333333
# Beverages, prepared with tap water, brewed, coffee === beverages prepared with tap water brewed coffee 0.9333333333333333
# Chicken, back meat only, BBQ, rotisserie, broiler === chicken back meat only bbq rotisserie broiler 0.9
# Drumstick pods, without salt, drained, boiled, cooked === drumstick pods without salt drained boiled cooked 0.9333333333333333
# Salad dressing, low calorie, mayonnaise and mayonnaise-type === salad dressing low calorie mayonnaise and mayonnaisetype 0.890909090909091
# Chrysanthemum, without salt, drained, boiled, cooked, garland === chrysanthemum without salt drained boiled cooked garland 0.9333333333333333
# Okra, without salt, drained, boiled, cooked, frozen === kale without salt drained boiled cooked frozen 0.9333333333333333
# Okra, without salt, drained, boiled, cooked, frozen === okra without salt drained boiled cooked frozen 0.9333333333333333
# Okra, without salt, drained, boiled, cooked, frozen === asparagus without salt drained boiled cooked frozen 0.9333333333333333
# T.G.I. FRIDAY'S, classic sirloin steak (10 oz) === tgi fridays classic sirloin steak 10 oz 0.8588235294117648
# Biscuits, prepared, dry mix, plain or buttermilk === biscuits prepared dry mix plain or buttermilk 0.9333333333333333
# Chicken, stewed, cooked, meat and skin, stewing === chicken stewed cooked meat and skin stewing 0.9333333333333333
ilers or fryers 0.9166666666666667
# Chicken, roasted, cooked, meat only, leg, broilers or fryers === chicken roasted cooked meat only leg broilers or fryers 0.9454545454545455
# Cheese spread, reduced fat, American or Cheddar cheese base === cheese spread reduced fat american or cheddar cheese base 0.9
# Pork, unheated, canned, extra lean and regular, ham, cured === pork unheated canned extra lean and regular ham cured 0.9454545454545455
# Bread, unenriched (includes corn muffin mix), dry mix, cornbread === bread unenriched includes corn muffin mix dry mix cornbread 0.9166666666666667
# Puddings, prepared with 2% milk, regular, dry mix, chocolate === puddings prepared with 2 milk regular dry mix chocolate 0.9333333333333333
# Beverages, frozen concentrate., with pulp, breakfast type, Orange-flavor drink === beverages frozen concentrate with pulp breakfast type orangeflavor drink 0.8933333333333334
# Pork, roasted, regular (approximately 11% fat), boneless, ham, cured === pork roasted regular approximately 11 fat boneless ham cured 0.9142857142857144
# Toaster Pastries, frosted (include apples, blueberry, cherry, strawberry), fruit === toaster pastries frosted include apples blueberry cherry strawberry fruit 0.9
# Cowpeas (blackeyes), without salt, drained, boiled, cooked, immature seeds === cowpeas blackeyes with salt drained boiled cooked immature seeds 0.9
# Cowpeas (blackeyes), without salt, drained, boiled, cooked, immature seeds === cowpeas blackeyes without salt drained boiled cooked immature seeds 0.9230769230769231
# Peas, without salt, drained, boiled, cooked, sprouted, mature seeds === peas without salt drained boiled cooked sprouted mature seeds 0.9454545454545455
# Pork, unheated, separable lean only, bone-in, slice, ham, cured === pork unheated separable lean only bonein slice ham cured 0.9
# Pork, unheated, separable lean only, bone-in, slice, ham, cured === pork unheated separable lean only bonein rump ham cured 0.8800000000000001
# Chesters flamin hot popcorn .875 ounces by Frito Lay === chesters flamin hot popcorn 875 ounces by frito lay 0.8923076923076924
# Cake, enriched, commercially prepared, cinnamon with crumb topping, coffeecake === cake enriched commercially prepared cinnamon with crumb topping coffeecake 0.9454545454545455
# Cheese, large or small curd, dry, uncreamed, nonfat, cottage === cheese large or small curd dry uncreamed nonfat cottage 0.9454545454545455
# Pie crust, chilled, vanilla wafer, prepared from recipe, cookie-type === pie crust chilled vanilla wafer prepared from recipe cookietype 0.9
# Cake, unenriched, other than all butter, commercially prepared, pound === cake unenriched other than all butter commercially prepared pound 0.9454545454545455
# Cake, unenriched, other than all butter, commercially prepared, pound === cake enriched other than all butter commercially prepared pound 0.9166666666666667
# Pork, raw, separable lean and fat, whole, loin, fresh === pork raw separable lean and fat whole loin fresh 0.9454545454545455
# Peas and onions, without salt, drained, boiled, cooked, frozen === peas and onions without salt drained boiled cooked frozen 0.9454545454545455
# Peas and onions, without salt, drained, boiled, cooked, frozen === peas and carrots without salt drained boiled cooked frozen 0.9166666666666667
# Beverages, decaffeinated, prepared with tap water, brewed, black, tea === beverages decaffeinated prepared with tap water brewed black tea 0.9454545454545455
# Chicken, roasted, cooked, meat only, wing, broilers or fryers === chicken roasted cooked meat only thigh broilers or fryers 0.9166666666666667
# Chicken, roasted, cooked, meat only, wing, broilers or fryers === chicken roasted cooked meat only back broilers or fryers 0.9166666666666667
# Chicken, roasted, cooked, meat only
# Lay's stax hot'n spicy barbecue flavored potato chips 5.5 ounce plastic canister by Frito Lay === lays stax hotn spicy barbecue flavored potato chips 55 ounce plastic canister by frito lay 0.8869565217391304
# Pork, roasted, heated, separable lean and fat, boneless, spiral slice, ham with natural juices, cured === pork roasted heated separable lean and fat boneless spiral slice ham with natural juices cured 0.9647058823529412
# Infant formula, with ARA and DHA, liquid concentrate not reconstituted, with iron, NUTRAMIGEN, ENFAMIL, MEAD JOHNSON === infant formula with ara and dha liquid concentrate not reconstituted with iron nutramigen enfamil mead johnson 0.8695652173913044
# Fruit roll-ups, fruit by the foot, gushers 16 count variety pack by GENERAL MILLS SALES INC. === fruit rollups fruit by the foot gushers 16 count variety pack by general mills sales inc 0.875
# Lay's kettle cooked sea salt & vinegar flavored potato chips 8.5 ounce plastic bags by Frito Lay === lays kettle cooked sea salt  vinegar flavored potato chips 85 ounce plastic bags by frito lay 0.9
# Pork, roasted, heated, separable lean only, boneless, meat only, spiral slice, ham with natural juices, cured === pork roasted heated separable lean only boneless meat only spiral slice ham with natural juices cured 0.9647058823529412
# Pork, raw, separable lean and fat, composite of trimmed retail cuts (leg, loin, shoulder, and spareribs), fresh === pork raw separable lean and fat composite of trimmed retail cuts leg loin shoulder and spareribs fresh 0.9500000000000001
# Cheetos crunchy cheese flavored snacks (12 - 1 ounce) 12 ounces 12 pack plastic bag by Frito Lay === cheetos crunchy cheese flavored snacks 12  1 ounce 12 ounces 12 pack plastic bag by frito lay 0.9142857142857144
# Lay's kettle cooked sea salt & cracked pepper flavored potato chips 8.5 ounce plastic bag by Frito Lay === lays kettle cooked sea salt  cracked pepper flavored potato chips 85 ounce plastic bag by frito lay 0.904
# Hits: 904

# %% [markdown]
# # Task 2

# %% [markdown]
# # Task 2.1 - Construct KG

# %%
# ! pip install rdflib

# %%
# Define namespaces

from rdflib import Graph, URIRef, Literal, XSD, Namespace, RDF

FOOD = Namespace('https://dbpedia.org/ontology/Food/')
NUTRITIONINFORMATION = Namespace('https://schema.org/NutritionInformation/')
FLAVOR = Namespace('https://dsci558.org/Flavor/')
FOODCATEGORY = Namespace('https://dsci558.org/FoodCategory/')

# %%
# Bind to knowledge graph

my_kg = Graph()
my_kg.bind('food', FOOD)
my_kg.bind('nutriinfo', NUTRITIONINFORMATION)
my_kg.bind('flavor', FLAVOR)
my_kg.bind('foodcategory', FOODCATEGORY)

# %%
# URI parser to replace space with hyfhen

def parseURI(identifier):
    return identifier.replace(' ', '-')

# %%
# Create nodes and insert into the KG

merged_df = pd.read_csv('merged_dataset.csv')
merged_df.Category = merged_df.Category.astype('string')

for index, row in merged_df.iterrows():
    g_title = row['Name']
    
    food_node_uri = URIRef(FOOD[parseURI(g_title)])

    my_kg.add((food_node_uri, RDF.type, FOOD['title']))
    my_kg.add((food_node_uri, FOOD['name'], Literal(g_title, datatype=XSD.string)))

    g_calories = row['Calories']
    g_fat = row['Fat']
    g_protein = row['Protein']
    g_sfa = row['Saturated_fatty_acids']
    g_vit_a = row['Vitamin_A_RAE']
    g_vit_b = row['Vitamin_B6']
    g_fatt = row['Fatty_acids_total_trans']
    g_vit_d = row['Vitamin_D']

    # Glycemic_Load,Completeness_Score,Amino_Acid_Score
    g_gl = row['Glycemic_Load']
    g_cs = row['Completeness_Score']
    g_aas = row['Amino_Acid_Score']

    g_category = row['Category']
    if(isinstance(g_category, str)):
        category_uri = URIRef(FOODCATEGORY[parseURI(g_category)])
        my_kg.add((category_uri, RDF.type, FOODCATEGORY['title']))

        my_kg.add((category_uri, FOODCATEGORY['has'], food_node_uri))

    # g_isbn13 = good_df['ISBN13'][good_index] if len(str(good_df['ISBN13'][good_index]).strip()) > 0 else barnes_df['ISBN13'][barnes_index]
    # g_pages = good_df['PageCount'][good_index] if len(str(good_df['PageCount'][good_index]).strip()) > 0 else barnes_df['Pages'][barnes_index]
    # g_author = good_df['FirstAuthor'][good_index] if len(str(good_df['FirstAuthor'][good_index]).strip()) > 0 else barnes_df['Author1'][barnes_index]

    if(len(str(g_calories).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['calories'], Literal(g_calories, datatype=XSD.float)))
    if(len(str(g_fat).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['fat'], Literal(g_fat, datatype=XSD.float)))
    if(len(str(g_protein).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['protein'], Literal(g_protein, datatype=XSD.float)))
    if(len(str(g_sfa).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['saturatedFattyAcids'], Literal(g_sfa, datatype=XSD.float))) 
    if(len(str(g_vit_a).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['vitA'], Literal(g_vit_a, datatype=XSD.float)))
    if(len(str(g_vit_b).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['vitB'], Literal(g_vit_b, datatype=XSD.float)))
    if(len(str(g_fatt).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['fattyAcidsTotalTrans'], Literal(g_fatt, datatype=XSD.float)))
    if(len(str(g_vit_d).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['vitD'], Literal(g_vit_d, datatype=XSD.float))) 
    if(len(str(g_gl).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['glycemicLoad'], Literal(g_gl, datatype=XSD.float)))
    if(len(str(g_cs).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['completenessScore'], Literal(g_cs, datatype=XSD.float)))
    if(len(str(g_aas).strip()) > 0):
        my_kg.add((food_node_uri, NUTRITIONINFORMATION['aminoAcidScore'], Literal(g_aas, datatype=XSD.float)))       
    # if(len(str(g_isbn13).strip()) > 0):
    #     my_kg.add((book_node_uri, BOOK['isbn'], Literal(g_isbn13, datatype=XSD.string)))
    # if(len(str(g_pages).strip()) > 0):
    #     my_kg.add((book_node_uri, BOOK['numberOfPages'], Literal(g_pages, datatype=XSD.positiveInteger)))

    # author_node_uri = URIRef(PERSON[parseURI(g_author)])

    # my_kg.add((author_node_uri, RDF.type, PERSON['name']))
    # my_kg.add((author_node_uri, PERSON['name'], Literal(g_author, datatype=XSD.string)))
    # my_kg.add((book_node_uri, BOOK['author'], author_node_uri))

    # g_rating_good = good_df['Rating'][good_index]
    # g_number_rating_good = good_df['NumberofRatings'][good_index]
    # g_number_review_good = good_df['NumberofReviews'][good_index]

    # g_sales_barnes = barnes_df['Salesrank'][barnes_index]
    # g_rating_count_barnes = barnes_df['Ratingscount'][barnes_index]
    # g_rating_value_barnes = barnes_df['Ratingvalue'][barnes_index]

    # if(len(str(g_rating_good).strip()) > 0 and len(str(g_rating_value_barnes).strip()) > 0):
    #     rating_node_uri = URIRef(RATING[parseURI(g_title)])
    #     my_kg.add((book_node_uri, RATING['aggregate'], Literal(str(g_rating_good)+"+"+str(g_rating_value_barnes))))
    #     my_kg.add((book_node_uri, RATING['good'], Literal(g_rating_good)))
    #     my_kg.add((book_node_uri, RATING['barnes'], Literal(g_rating_value_barnes)))

    #     my_kg.add((book_node_uri, RATING['goodNumRating'], Literal(g_number_rating_good)))
    #     my_kg.add((book_node_uri, RATING['goodNumReview'], Literal(g_number_review_good)))
    #     my_kg.add((book_node_uri, RATING['barnesNumRating'], Literal(g_rating_count_barnes)))
    #     my_kg.add((book_node_uri, RATING['barnesSale'], Literal(g_sales_barnes)))

    #     my_kg.add((book_node_uri, BOOK['aggregateRating'], rating_node_uri))


    # g_publisher = good_df['Publisher'][good_index] if len(str(good_df['Publisher'][good_index])) > 0 else barnes_df['Publisher'][barnes_index]
    # g_publish_date = good_df['PublishDate'][good_index] if len(str(good_df['PublishDate'][good_index])) > 0 else barnes_df['PublicationDate'][barnes_index]

    # if(len(str(g_publish_date).strip()) > 0):
    #     my_kg.add((book_node_uri, BOOK['datePublished'], Literal(g_publish_date, datatype=XSD.string)))

    # if(len(str(g_publisher)) > 0):
    #     publisher_node_uri = URIRef(PUBLISHER[parseURI(g_publisher)])
    #     my_kg.add((book_node_uri, BOOK['publisher'], rating_node_uri))
        

    # g_format = good_df['Format'][good_index]
    # g_lang = good_df['Language'][good_index]

    # g_paperback_price = barnes_df['Paperbackprice'][barnes_index].replace('$', '')
    # g_hardcover_price = barnes_df['Hardcoverprice'][barnes_index].replace('$', '')
    # g_nookbook_price = barnes_df['Nookbookprice'][barnes_index].replace('$', '')
    # g_audiobook_price = barnes_df['Audiobookprice'][barnes_index].replace('$', '')


    # price_node_uri = URIRef(PRICE[parseURI(g_title)])
    
    # if(len(str(g_paperback_price).strip()) > 0):
    #     my_kg.add((price_node_uri, PRICE['paperback'], Literal(float(g_paperback_price))))
    # if(len(str(g_hardcover_price).strip()) > 0):
    #     my_kg.add((price_node_uri, PRICE['hardcover'], Literal(float(g_hardcover_price))))
    # if(len(str(g_nookbook_price).strip()) > 0):
    #     my_kg.add((price_node_uri, PRICE['nookbook'], Literal(float(g_nookbook_price))))
    # if(len(str(g_audiobook_price).strip()) > 0):
    #     my_kg.add((price_node_uri, PRICE['audiobook'], Literal(float(g_audiobook_price))))

    # my_kg.add((book_node_uri, BOOK['cost'], rating_node_uri))

from itertools import combinations

hit_count = 0

for key, value in flavor_dict.items():
    for pair in list(combinations(value, 2)):
        # try:
        food_uri_1 = URIRef(FOOD[parseURI(pair[0])])
        food_uri_2 = URIRef(FOOD[parseURI(pair[1])])
        # except KeyError:
        #     continue

        my_kg.add((food_uri_1, FLAVOR['flavorOf'], food_uri_2))
        my_kg.add((food_uri_2, FLAVOR['flavorOf'], food_uri_1))
        hit_count += 1

print("Hits:", hit_count)
# Out:
# Hits: 20307

# %%
# Serialize graph and dump to file

my_kg.serialize('large_graph.ttl', format="turtle")
# Out:
# <Graph identifier=N2f9ad2027b6248f89e625a5c0e55c004 (<class 'rdflib.graph.Graph'>)>
